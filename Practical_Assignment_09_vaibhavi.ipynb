# %% [markdown]
#  ### Write a python program to load dataset related to tips given in restaurant and display a pie chart to compare percentage of people in smoking area vs non smoking area :

# %%
import pandas as pd
import numpy as np

# It loads The Data 
df = pd.DataFrame(data)
print(df.head(30))
df.to_csv('tips.csv', index=False)
# Out:
#     Customer ID  Total Bill  Tip Amount Smoking       Date
# 0             1      975.65       83.48      No 2023-01-01
# 1             2      455.28       52.17      No 2023-01-02
# 2             3      461.51       15.65     Yes 2023-01-03
# 3             4      974.62       19.08     Yes 2023-01-04
# 4             5      620.89       72.09     Yes 2023-01-05
# 5             6      434.43       54.68     Yes 2023-01-06
# 6             7      845.59       89.45      No 2023-01-07
# 7             8      216.79       57.55      No 2023-01-08
# 8             9      605.71       33.92      No 2023-01-09
# 9            10      244.42       60.14      No 2023-01-10
# 10           11      332.84       37.79     Yes 2023-01-11
# 11           12      458.25       17.49     Yes 2023-01-12
# 12           13      403.48       90.45      No 2023-01-13
# 13           14      422.36       68.83      No 2023-01-14
# 14           15      971.64       12.59      No 2023-01-15
# ...

# %%
###  Draw a Graph Depicting Percentage of Smoking vs Non-Smoking Customers Using Pie Chart
# Pie chart
smoking_counts = df['Smoking'].value_counts()
plt.pie(smoking_counts, labels=smoking_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Smoking vs Non-Smoking Customers')
plt.show()

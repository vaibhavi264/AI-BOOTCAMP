# %% [markdown]
#  ### Write python program using nltk library to load the text on topic of your choice and generate a word cloud from it. You may refer modules required for the same in google classroom.

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Import necessary libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Ensure necessary NLTK data is downloaded
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ICEEM\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ICEEM\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Provided text
text = """
 Natural language processing (NLP) is a field of artificial intelligence
that focuses on the interaction between computers and humans through natural language.
It involves the development of algorithms that allow computers to process and understand human languages
in a way that is both meaningful and useful. NLP has applications in various fields, including
speech recognition, sentiment analysis, and machine translation.
"""
print(text)
# Out:
#  Natural language processing (NLP) is a field of artificial intelligence
# that focuses on the interaction between computers and humans through natural language.
# It involves the development of algorithms that allow computers to process and understand human languages
# in a way that is both meaningful and useful. NLP has applications in various fields, including
# speech recognition, sentiment analysis, and machine translation.

# %%
# Tokenization of words
words = word_tokenize(text.lower())  # Convert to lowercase for uniformity
print(words)
# Out:
# ['natural', 'language', 'processing', '(', 'nlp', ')', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'focuses', 'on', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'through', 'natural', 'language', '.', 'it', 'involves', 'the', 'development', 'of', 'algorithms', 'that', 'allow', 'computers', 'to', 'process', 'and', 'understand', 'human', 'languages', 'in', 'a', 'way', 'that', 'is', 'both', 'meaningful', 'and', 'useful', '.', 'nlp', 'has', 'applications', 'in', 'various', 'fields', ',', 'including', 'speech', 'recognition', ',', 'sentiment', 'analysis', ',', 'and', 'machine', 'translation', '.']

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
# The general syntax for a list comprehension is: [expression for item in iterable if condition]
print(filtered_words)
# Out:
# ['natural', 'language', 'processing', 'nlp', 'field', 'artificial', 'intelligence', 'focuses', 'interaction', 'computers', 'humans', 'natural', 'language', 'involves', 'development', 'algorithms', 'allow', 'computers', 'process', 'understand', 'human', 'languages', 'way', 'meaningful', 'useful', 'nlp', 'applications', 'various', 'fields', 'including', 'speech', 'recognition', 'sentiment', 'analysis', 'machine', 'translation']

# %%
# Frequency distribution of words
word_freq = Counter(filtered_words)
print(word_freq)
# Out:
# Counter({'natural': 2, 'language': 2, 'nlp': 2, 'computers': 2, 'processing': 1, 'field': 1, 'artificial': 1, 'intelligence': 1, 'focuses': 1, 'interaction': 1, 'humans': 1, 'involves': 1, 'development': 1, 'algorithms': 1, 'allow': 1, 'process': 1, 'understand': 1, 'human': 1, 'languages': 1, 'way': 1, 'meaningful': 1, 'useful': 1, 'applications': 1, 'various': 1, 'fields': 1, 'including': 1, 'speech': 1, 'recognition': 1, 'sentiment': 1, 'analysis': 1, 'machine': 1, 'translation': 1})

# %%
# Create a WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# %%
# Plotting the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axes
plt.show()
